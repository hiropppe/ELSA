# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib
font = {"family":"IPAexGothic"}
matplotlib.rc('font', **font)

pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv("/data/elsa/ja_emoji.txt", delimiter="\t", header=None)
df
# Out:
#        0       1
# 0      ✨  284698
# 1      😭  162125
# 2      😊  159170
# 3      ❤  120413
# 4      💦  116631
# 5      ☺  104356
# 6      😂   91444
# 7      💕   82436
# 8      🤔   74905
# 9      ❗   72051
# 10     😅   68287
# 11     🥺   62806
# 12     😆   62289
# 13     ♥   61657
# 14     🙇   55342
# 15     😢   51752
# 16     👍   50492
# 17     🤣   43628
# 18     😍   42152
# 19     😇   41942
# 20     🥰   38893
# 21     🙏   36062
# 22     🎵   33080
# 23     ❣   31117
# 24     😌   30773
# 25     😃   30546
# 26     😁   29071
# 27     💓   28654
# 28     🤗   28023
# 29     ☀   27682
# 30     😳   26172
# 31     🙄   24756
# 32     💪   23166
# 33     🎉   22703
# 34     🤦   22661
# 35     💖   21269
# 36     🎶   21235
# 37     🙌   21229
# 38     💗   21031
# 39     ✌   20439
# 40     🎊   20363
# 41     🔥   19619
# 42     🙋   19428
# 43     😄   19090
# 44     😉   18896
# 45     🎁   18804
# 46     🙆   18164
# 47     🤤   17894
# 48     😱   17086
# 49     🌸   15287
# 50     👀   14665
# ...

# %%
df = pd.read_csv("/data/topic-detection/emoji/ja_emoji_tokens.txt", header=None, delimiter=",")
df
# Out:
#                                                         0              1
# 0                                                   いく 若い              🥺
# 1                                   土下座 !! フォロバ ありがとう ハート              ♀
# 2                                       ねね 尾羽 ω ) 休み 満喫 ω            ✨ ☀
# 3                          健ちゃん 隆二 くん 絡む 面白い 思う ReTweet ?              ✨
# 4                                            nos 飲む 勇気 出る              🥺
# 5       サルガタナス 育成 ミツクビ vh 金冠 とる 束縛 ターン 巡 かける オロバス 脚 遅い...              🥺
# 6                                  ありがとう з ィェーィ ( ' ω ' )              ✌
# 7       こんにちは 唯人 フォロー ありがとう ! プラベ 入れ違う しまう 今度 一緒 遊べる 嬉...              ☺
# 8                                         読む 画像 見せる 持つ !!          ✨ 💕 🥺
# 9                                            エアショ 男の子 ほしい              🥺
# 10      あむ にゃんにゃん しかめっ面 しかめっ面 しかめっ面 しかめっ面 しかめっ面 しかめっ面 ...              🤟
# 11           教える ニュース : joy 結婚 Instagram 女神 わたなべ麻衣 可愛い わぁ              ❣
# ...

# %%
df = pd.read_csv("/root/topic-model/nctm.rxp", header=None, delimiter=" ")
df.head(100)
# Out:
#     0      1      2
# 0   👍  0.860  0.121
# 1   🥳  0.837  0.162
# 2   🌸  0.826  0.152
# 3   🤝  0.798  0.105
# 4   💟  0.783  0.000
# 5   😢  0.783  0.144
# 6   🤞  0.773  0.052
# 7   🙌  0.769  0.209
# 8   💞  0.756  0.234
# 9   🍀  0.755  0.187
# 10  🙈  0.752  0.000
# 11  💕  0.746  0.252
# 12  💮  0.739  0.000
# 13  💗  0.732  0.265
# 14  💖  0.729  0.268
# 15  🌈  0.727  0.241
# 16  💘  0.695  0.274
# 17  💭  0.685  0.297
# 18  🐣  0.679  0.073
# 19  🥺  0.679  0.321
# 20  🐶  0.678  0.192
# 21  💐  0.671  0.246
# 22  💫  0.669  0.278
# 23  🦖  0.664  0.323
# 24  🤟  0.664  0.334
# 25  💯  0.663  0.111
# 26  🥴  0.656  0.341
# 27  🙏  0.654  0.339
# 28  💓  0.650  0.348
# 29  🌟  0.650  0.329
# 30  🥰  0.650  0.350
# 31  😭  0.630  0.352
# 32  🧚  0.625  0.368
# 33  💌  0.620  0.188
# 34  🤚  0.617  0.179
# 35  😳  0.615  0.267
# 36  🤤  0.611  0.297
# 37  🤙  0.607  0.234
# 38  🌼  0.606  0.326
# 39  🤦  0.604  0.229
# 40  🦢  0.602  0.306
# 41  🐨  0.595  0.000
# 42  💍  0.586  0.215
# 43  🦙  0.581  0.320
# ...

# %%
df = pd.read_csv("/data/topic-detection/emoji/ja_emoji_tokens.txt", header=None, delimiter=",")
emojis = df[1].values

emojiis = []
for emoji in emojis:
    emojiis.extend(emoji.split())
    
df = pd.DataFrame({"emoji": emojiis})
df["emoji"].value_counts().head(100)
# Out:
# 🥺    91925
# ♀    75538
# ✨    66780
# 🥰    52515
# ♂    47243
# ❤    29433
# ☺    19493
# ♥    15258
# 🥳    11461
# ✌     7632
# 💕     7001
# 🧡     5945
# ☝     4946
# 💓     4839
# 🤟     4733
# ❗     4681
# ❣     4266
# ☀     4214
# 🤲     3667
# 💖     3410
# 💗     3318
# 🥴     3038
# ✋     2476
# ❕     2395
# 🥵     2389
# ⚰     2273
# 🧸     2265
# ✊     1940
# 🥶     1786
# ❔     1741
# 💪     1599
# 🙏     1574
# 🧚     1558
# ⭐     1535
# 💦     1370
# ❓     1354
# ⬇     1297
# 🎉     1233
# 💜     1220
# ☁     1197
# ➡     1195
# ⤴     1167
# 👏     1160
# 💞     1013
# ☂      978
# 🥩      971
# 💙      969
# 👐      953
# ☔      929
# ⚡      910
# 🧞      870
# 🥤      858
# 💛      836
# ☪      830
# 💚      793
# 🦖      779
# ⤵      723
# ✍      716
# 🥦      676
# ☕      657
# ⚠      588
# 🥟      575
# 🦸      562
# ®      560
# 💭      559
# 🧠      556
# 🎶      550
# 😭      542
# 🔥      535
# 👍      534
# 🦔      533
# 🌟      484
# 🧟      481
# ➰      470
# ❄      455
# 🌸      454
# ...
